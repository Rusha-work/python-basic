# %% [markdown]
# # **PYTHON  BASICS**

# %% [markdown]
# 1. What's python & why is it popular?
#    - Python is a programming language which was developed around 1991 . It is popular for various reasons. Which are as follows ;
#     1.  It's easy to learn .
#     2.  It has a lot of libraries.
#     3. It's easy to read and it also has has huge community.
#     4. It's versitable.
# 2.What's an interpreter in python?
#  - It's a program that reads& executes python code for us to see results Immediately.Immediately.It translates the code into machine readable language.
# 3. What're pre-defined keywords in python ?
#   - these're pre-defined words that hold special meaning.meanireng.They' used for specific purposes.purposes.Like - Print,if,type etc.
# 4.Can keywords be used as variable name?
#    - No,variable is a reserved memory space for storing values.values. So keywords can't be used.used. keywords are uesd for performing certain tasks within python.
# 5. What's Mutability in python?
#  -  Mutability in python refers to the changeable value of objects which is already created.created.i.created.created.i.e it can be changed after being created.
# 6. Why lists are mutable but tuples are immutable?
#   -  Items can be assigned to list.list.But it can't be done to tuples. The contents can be changed in lists but in tuples it's not possible. So, tupletuples are more memory efficient.
# 7.What is the difference between '== '& is operators in Python?
#  - In python '==' compares the value of different objects  & 'is'  sees if it refers to the same object in memory.
# 8.What are logical operators in Python?
#  - logical operators help to evaluate multiple conditions by determining overall true value.value.like - and, or & not.
# 9.What is type casting in Python?
#  - the process of changing data type of any object~
#  or values is known as type casting.Because there can be mismatch between the data types.
# 10.  What is the difference between implicit and explicit type casting?
#  - In case of implicit type casting python understands the data & works accordingly. In case of
#  explicit type casting we've to convert the data type by using inbuilt functions.
# 11. What is the  purpose of conditional statements in Python?
#  - The  purpose of conditional statements in Python are ; a) it helps to deal with real life situations as involves lots of conditions with various outcomes.
#  b) they control the flow of code executexecution.
#  c)they can improve programming efficiency.
# 12.How does the elif statement work?
#  - It's used in python to check multiple conditions. If the condition is false then it moves to the next condition through  using this keyword.
# 13. What is the difference between for and while loops?
#  - While loops  represents  continuous repetition of a block of code until a certain condition is made. And for loops represent  iteration of a sequence of elements.
# 14. Describe a scenario where  while loop is more suitable than for loop.
#  - Promting a user for input until a valid response is achieved - could be a scenario  where  while loop is more suitable than for loop. As no. of iteration is unknown in advance.

# %%
# 1. write a Python program to print "Hello world!_
'''print ("Hello world!")'''
# Out:
#   File "<ipython-input-8-0bc851b80645>", line 2
#     print ("Hello world!")
#     ^
# IndentationError: unexpected indent

# %%
#  2. Write a program that displays your name and age.
'''print ("name = Rusha Das
           age = 20")'''

# %%
# 3. Write code to print all the pre-defined keywords in Python using the keyword library.
'''print ("the pre-defined keywords in python are :")
import keyworkeyword
print ("keyword, kwlist")'''

# %%
# 4. write a program that checks if a given word is a Python keyword.
''' word = input("enter a word: ")
 if word =python keyword:
   print ("python keyword")
 else:
    print ("not a keyword")'''

# %%
# 5. Create a list and tuple in Python and demonstrate how attempting to change an element works differently for each.
 ''' My_List= [1,2,3,"Rusha",6.5]
     My_List[3]="Ajay"
     Tuple = [1,2,4.5,5.6,"Bijay"]
      My_Lists = list(Tuple )
       My_Lists[2]=9'''

# %%
# 6.Write a function to demonstrate the behavior of mutable and immutable arguments.
'''My_List= [1,2,3,"Rusha",6.5]
     My_List[3]="Ajay"
      Tuple = [1,2,4.5,5.6,"Bijay"]
      TTuple[4]=9'''

# From this we can see that tuple cannot be changed as it's immutable object.

# %%
# 8.Write a program to demonstrate the use of logical operators.
  '''35<<3'''

  # whose ans is 280

# %%
# 9.Write a Python program to convert user input from string to integer float and boolean types.
'''a="10"
  int(a)
  float(a)
  bool(a)'''

# %%
# 10. Write code to deMonstrAte typecasting with list elements.
''' My_List= [1,2,3,"Rusha",6.5]
    int(My_List)'''

# %%
# 11. Write A program that checks if a number is positive negetive or zerzero.
'''a = 12
   if a>0:
    print ("Positive")
  elif a<0:

     print ("negetive")
     else:
      print("zero")

# %%
# 12.Write a for loop  to print numbers from 1 to 100.
'''for i in range(1,100):
   print(i,end =" ")'''

# %%
# 13.Write a Python progam to find  sum of all even numbers between 1 and 500.
'''for i in range(1,500)
   if i%2 == 0:
    print(i,end =" ")'''
